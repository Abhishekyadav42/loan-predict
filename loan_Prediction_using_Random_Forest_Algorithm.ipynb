# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"D:\train_ctrUa4K.csv")

# %%
Df = pd.read_csv(r"D:\test_lAUu6dG.csv")

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
Df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# 1               3076               1500       126.0             360.0
# 2               5000               1800       208.0             360.0
# 3               2340               2546       100.0             360.0
# 4               3276                  0        78.0             360.0
# ..               ...                ...         ...               ...
# 362             4009               1777       113.0             360.0
# 363             4158                709       115.0             360.0
# 364             3250               1993       126.0             360.0
# 365             5000               2393       158.0             360.0
# 366             9200                  0        98.0             180.0
#
#      Credit_History Property_Area
# 0               1.0         Urban
# 1               1.0         Urban
# 2               1.0         Urban
# 3               NaN         Urban
# 4               1.0         Urban
# ..              ...           ...
# 362             1.0         Urban
# 363             1.0         Urban
# 364             NaN     Semiurban
# 365             1.0         Rural
# 366             1.0         Rural
#
# [367 rows x 12 columns]

# %%
df.shape
# Out:
# (614, 13)

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isna().any()
# Out:
# Loan_ID              False
# Gender                True
# Married               True
# Dependents            True
# Education            False
# Self_Employed         True
# ApplicantIncome      False
# CoapplicantIncome    False
# LoanAmount            True
# Loan_Amount_Term      True
# Credit_History        True
# Property_Area        False
# Loan_Status          False
# dtype: bool

# %%
df[Df.columns[Df.isna().any()]]
# Out:
#      Gender Dependents Self_Employed  LoanAmount  Loan_Amount_Term  \
# 0      Male          0            No         NaN             360.0
# 1      Male          1            No       128.0             360.0
# 2      Male          0           Yes        66.0             360.0
# 3      Male          0            No       120.0             360.0
# 4      Male          0            No       141.0             360.0
# ..      ...        ...           ...         ...               ...
# 609  Female          0            No        71.0             360.0
# 610    Male         3+            No        40.0             180.0
# 611    Male          1            No       253.0             360.0
# 612    Male          2            No       187.0             360.0
# 613  Female          0           Yes       133.0             360.0
#
#      Credit_History
# 0               1.0
# 1               1.0
# 2               1.0
# 3               1.0
# 4               1.0
# ..              ...
# 609             1.0
# 610             1.0
# 611             1.0
# 612             1.0
# 613             0.0
#
# [614 rows x 6 columns]

# %%
print(df['Gender'].isna().sum())
print(df["Married"].isna().sum())
print(df['Dependents'].isna().sum())
print(df["Self_Employed"].isna().sum())
print(df['LoanAmount'].isna().sum())
print(df["Loan_Amount_Term"].isna().sum())
print(df['Credit_History'].isna().sum())
# Out:
# 13
# 3
# 15
# 32
# 22
# 14
# 50

# %%
df["Gender"].value_counts()
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64

# %%
df["Married"].value_counts()
# Out:
# Yes    398
# No     213
# Name: Married, dtype: int64

# %%
df["Dependents"].value_counts()
# Out:
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: Dependents, dtype: int64

# %% [markdown]
# # important Changes 3+ to 4 in Dependents column¶

# %%
df['Dependents'] = Df['Dependents'].replace(to_replace = '3+', value = 4)

# %%
df["Dependents"].value_counts()
# Out:
# 0    200
# 2     59
# 1     58
# 4     40
# Name: Dependents, dtype: int64

# %%
df["Self_Employed"].value_counts()
# Out:
# No     500
# Yes     82
# Name: Self_Employed, dtype: int64

# %%
df["LoanAmount"].value_counts()
# Out:
# 120.0    20
# 110.0    17
# 100.0    15
# 160.0    12
# 187.0    12
#          ..
# 240.0     1
# 214.0     1
# 59.0      1
# 166.0     1
# 253.0     1
# Name: LoanAmount, Length: 203, dtype: int64

# %%
df["Loan_Amount_Term"].value_counts()
# Out:
# 360.0    512
# 180.0     44
# 480.0     15
# 300.0     13
# 240.0      4
# 84.0       4
# 120.0      3
# 60.0       2
# 36.0       2
# 12.0       1
# Name: Loan_Amount_Term, dtype: int64

# %%
df["Credit_History"].value_counts()
# Out:
# 1.0    475
# 0.0     89
# Name: Credit_History, dtype: int64

# %%
df["Loan_Status"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # fill up NAN value by Mean

# %%
df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])
df['Married'] = df['Married'].fillna(df['Married'].mode()[0])
df['Dependents'] = df['Dependents'].fillna(df['Dependents'].mode()[0])
df['Self_Employed'] = df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])
df['LoanAmount'] = df['LoanAmount'].fillna(df['LoanAmount'].mean())
df['Loan_Amount_Term'] = df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())
df['Credit_History'] = df['Credit_History'].fillna(df['Credit_History'].mode()[0])

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          2      Graduate           Yes
# 3    LP001006    Male     Yes          2  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          0      Graduate            No
# 611  LP002983    Male     Yes          0      Graduate            No
# 612  LP002984    Male     Yes          0      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0  146.412162             360.0
# 1               4583             1508.0  128.000000             360.0
# 2               3000                0.0   66.000000             360.0
# 3               2583             2358.0  120.000000             360.0
# 4               6000                0.0  141.000000             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0   71.000000             360.0
# 610             4106                0.0   40.000000             180.0
# 611             8072              240.0  253.000000             360.0
# 612             7583                0.0  187.000000             360.0
# 613             4583                0.0  133.000000             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
df.isna().any()
# Out:
# Loan_ID              False
# Gender               False
# Married              False
# Dependents           False
# Education            False
# Self_Employed        False
# ApplicantIncome      False
# CoapplicantIncome    False
# LoanAmount           False
# Loan_Amount_Term     False
# Credit_History       False
# Property_Area        False
# Loan_Status          False
# dtype: bool

# %% [markdown]
# # data set convert into Numerical Form

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
df['Gender']= label_encoder.fit_transform(df['Gender'])
df['Married']= label_encoder.fit_transform(df['Married'])
df['Education']= label_encoder.fit_transform(df['Education'])
df['Self_Employed']= label_encoder.fit_transform(df['Self_Employed'])
df['Property_Area']= label_encoder.fit_transform(df['Property_Area'])
df['Loan_Status']= label_encoder.fit_transform(df['Loan_Status'])

# %%
df
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001002       1        0          0          0              0
# 1    LP001003       1        1          1          0              0
# 2    LP001005       1        1          2          0              1
# 3    LP001006       1        1          2          1              0
# 4    LP001008       1        0          0          0              0
# ..        ...     ...      ...        ...        ...            ...
# 609  LP002978       0        0          0          0              0
# 610  LP002979       1        1          0          0              0
# 611  LP002983       1        1          0          0              0
# 612  LP002984       1        1          0          0              0
# 613  LP002990       0        0          0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0  146.412162             360.0
# 1               4583             1508.0  128.000000             360.0
# 2               3000                0.0   66.000000             360.0
# 3               2583             2358.0  120.000000             360.0
# 4               6000                0.0  141.000000             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0   71.000000             360.0
# 610             4106                0.0   40.000000             180.0
# 611             8072              240.0  253.000000             360.0
# 612             7583                0.0  187.000000             360.0
# 613             4583                0.0  133.000000             360.0
#
#      Credit_History  Property_Area  Loan_Status
# 0               1.0              2            1
# 1               1.0              0            0
# 2               1.0              2            1
# 3               1.0              2            1
# 4               1.0              2            1
# ..              ...            ...          ...
# 609             1.0              0            1
# 610             1.0              0            1
# 611             1.0              2            1
# 612             1.0              2            1
# 613             0.0              1            0
#
# [614 rows x 13 columns]

# %%
Df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# 1               3076               1500       126.0             360.0
# 2               5000               1800       208.0             360.0
# 3               2340               2546       100.0             360.0
# 4               3276                  0        78.0             360.0
# ..               ...                ...         ...               ...
# 362             4009               1777       113.0             360.0
# 363             4158                709       115.0             360.0
# 364             3250               1993       126.0             360.0
# 365             5000               2393       158.0             360.0
# 366             9200                  0        98.0             180.0
#
#      Credit_History Property_Area
# 0               1.0         Urban
# 1               1.0         Urban
# 2               1.0         Urban
# 3               NaN         Urban
# 4               1.0         Urban
# ..              ...           ...
# 362             1.0         Urban
# 363             1.0         Urban
# 364             NaN     Semiurban
# 365             1.0         Rural
# 366             1.0         Rural
#
# [367 rows x 12 columns]

# %%
Df.shape
# Out:
# (367, 12)

# %%
Df.isna().any()
# Out:
# Loan_ID              False
# Gender                True
# Married              False
# Dependents            True
# Education            False
# Self_Employed         True
# ApplicantIncome      False
# CoapplicantIncome    False
# LoanAmount            True
# Loan_Amount_Term      True
# Credit_History        True
# Property_Area        False
# dtype: bool

# %%
print(Df['Gender'].isna().sum())
print(Df["Married"].isna().sum())
print(Df['Dependents'].isna().sum())
print(Df["Self_Employed"].isna().sum())
print(Df['LoanAmount'].isna().sum())
print(Df["Loan_Amount_Term"].isna().sum())
print(Df['Credit_History'].isna().sum())
# Out:
# 11
# 0
# 10
# 23
# 5
# 6
# 29

# %%
Df['Dependents'] = Df['Dependents'].replace(to_replace = '3+', value = 4)
Df["Dependents"].value_counts()
# Out:
# 0    200
# 2     59
# 1     58
# 4     40
# Name: Dependents, dtype: int64

# %%
Df['Gender'] = Df['Gender'].fillna(Df['Gender'].mode()[0])
Df['Married'] = Df['Married'].fillna(Df['Married'].mode()[0])
Df['Dependents'] = Df['Dependents'].fillna(Df['Dependents'].mode()[0])
Df['Self_Employed'] = Df['Self_Employed'].fillna(Df['Self_Employed'].mode()[0])
Df['LoanAmount'] = Df['LoanAmount'].fillna(Df['LoanAmount'].mean())
Df['Loan_Amount_Term'] = Df['Loan_Amount_Term'].fillna(Df['Loan_Amount_Term'].mean())
Df['Credit_History'] = Df['Credit_History'].fillna(Df['Credit_History'].mode()[0])

# %%
Df.isna().any()
# Out:
# Loan_ID              False
# Gender               False
# Married              False
# Dependents           False
# Education            False
# Self_Employed        False
# ApplicantIncome      False
# CoapplicantIncome    False
# LoanAmount           False
# Loan_Amount_Term     False
# Credit_History       False
# Property_Area        False
# dtype: bool

# %%
# Import label encoder
from sklearn import preprocessing
  
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# Encode labels in column 'species'.
Df['Gender']= label_encoder.fit_transform(Df['Gender'])
Df['Married']= label_encoder.fit_transform(Df['Married'])
Df['Education']= label_encoder.fit_transform(Df['Education'])
Df['Self_Employed']= label_encoder.fit_transform(Df['Self_Employed'])
Df['Property_Area']= label_encoder.fit_transform(Df['Property_Area'])
#test['Loan_Status']= label_encoder.fit_transform(test['Loan_Status'])

# %%
Df
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001015       1        1          0          0              0
# 1    LP001022       1        1          1          0              0
# 2    LP001031       1        1          2          0              0
# 3    LP001035       1        1          2          0              0
# 4    LP001051       1        0          0          1              0
# ..        ...     ...      ...        ...        ...            ...
# 362  LP002971       1        1          4          1              1
# 363  LP002975       1        1          0          0              0
# 364  LP002980       1        0          0          0              0
# 365  LP002986       1        1          0          0              0
# 366  LP002989       1        0          0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# 1               3076               1500       126.0             360.0
# 2               5000               1800       208.0             360.0
# 3               2340               2546       100.0             360.0
# 4               3276                  0        78.0             360.0
# ..               ...                ...         ...               ...
# 362             4009               1777       113.0             360.0
# 363             4158                709       115.0             360.0
# 364             3250               1993       126.0             360.0
# 365             5000               2393       158.0             360.0
# 366             9200                  0        98.0             180.0
#
#      Credit_History  Property_Area
# 0               1.0              2
# 1               1.0              2
# 2               1.0              2
# 3               1.0              2
# 4               1.0              2
# ..              ...            ...
# 362             1.0              2
# 363             1.0              2
# 364             1.0              1
# 365             1.0              0
# 366             1.0              0
#
# [367 rows x 12 columns]

# %%
Df = Df.iloc[:,1:12]
Df
# Out:
#      Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        1          0          0              0             5720
# 1         1        1          1          0              0             3076
# 2         1        1          2          0              0             5000
# 3         1        1          2          0              0             2340
# 4         1        0          0          1              0             3276
# ..      ...      ...        ...        ...            ...              ...
# 362       1        1          4          1              1             4009
# 363       1        1          0          0              0             4158
# 364       1        0          0          0              0             3250
# 365       1        1          0          0              0             5000
# 366       1        0          0          0              1             9200
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                    0       110.0             360.0             1.0
# 1                 1500       126.0             360.0             1.0
# 2                 1800       208.0             360.0             1.0
# 3                 2546       100.0             360.0             1.0
# 4                    0        78.0             360.0             1.0
# ..                 ...         ...               ...             ...
# 362               1777       113.0             360.0             1.0
# 363                709       115.0             360.0             1.0
# 364               1993       126.0             360.0             1.0
# 365               2393       158.0             360.0             1.0
# 366                  0        98.0             180.0             1.0
#
#      Property_Area
# 0                2
# 1                2
# 2                2
# 3                2
# 4                2
# ..             ...
# 362              2
# 363              2
# 364              1
# 365              0
# 366              0
#
# [367 rows x 11 columns]

# %%
# Extract Independent and dependent Variables
X_df = df.iloc[:,1:12]
X_df
# Out:
#      Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0          0          0              0             5849
# 1         1        1          1          0              0             4583
# 2         1        1          2          0              1             3000
# 3         1        1          2          1              0             2583
# 4         1        0          0          0              0             6000
# ..      ...      ...        ...        ...            ...              ...
# 609       0        0          0          0              0             2900
# 610       1        1          0          0              0             4106
# 611       1        1          0          0              0             8072
# 612       1        1          0          0              0             7583
# 613       0        0          0          0              1             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0  146.412162             360.0             1.0
# 1               1508.0  128.000000             360.0             1.0
# 2                  0.0   66.000000             360.0             1.0
# 3               2358.0  120.000000             360.0             1.0
# 4                  0.0  141.000000             360.0             1.0
# ..                 ...         ...               ...             ...
# 609                0.0   71.000000             360.0             1.0
# 610                0.0   40.000000             180.0             1.0
# 611              240.0  253.000000             360.0             1.0
# 612                0.0  187.000000             360.0             1.0
# 613                0.0  133.000000             360.0             0.0
#
#      Property_Area
# 0                2
# 1                0
# 2                2
# 3                2
# 4                2
# ..             ...
# 609              0
# 610              0
# 611              2
# 612              2
# 613              1
#
# [614 rows x 11 columns]

# %%
y_df = df.Loan_Status
y_df
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 614, dtype: int32

# %%
X = DF.iloc[:,1:12]
y = DF.iloc[:,12]

print(y.value_counts())
pd.crosstab(index=y,columns='prop',normalize='all')
# Out:
# 1    422
# 0    192
# Name: Loan_Status, dtype: int64
# col_0            Prop
# Loan_Status
# 0            0.312704
# 1            0.687296

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
regressor = RandomForestClassifier()
model = RandomForestClassifier(n_estimators=200, min_samples_split=100, max_depth=7, max_features=1)

model.fit(X_df,y_df)
# Out:
# RandomForestClassifier(max_depth=7, max_features=1, min_samples_split=100,
#                        n_estimators=200)

# %%
y_pred = model.predict(Df)

# %%
y_pred.shape
# Out:
# (367,)

# %%
Df
# Out:
#      Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        1          0          0              0             5720
# 1         1        1          1          0              0             3076
# 2         1        1          2          0              0             5000
# 3         1        1          2          0              0             2340
# 4         1        0          0          1              0             3276
# ..      ...      ...        ...        ...            ...              ...
# 362       1        1          4          1              1             4009
# 363       1        1          0          0              0             4158
# 364       1        0          0          0              0             3250
# 365       1        1          0          0              0             5000
# 366       1        0          0          0              1             9200
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                    0       110.0             360.0             1.0
# 1                 1500       126.0             360.0             1.0
# 2                 1800       208.0             360.0             1.0
# 3                 2546       100.0             360.0             1.0
# 4                    0        78.0             360.0             1.0
# ..                 ...         ...               ...             ...
# 362               1777       113.0             360.0             1.0
# 363                709       115.0             360.0             1.0
# 364               1993       126.0             360.0             1.0
# 365               2393       158.0             360.0             1.0
# 366                  0        98.0             180.0             1.0
#
#      Property_Area
# 0                2
# 1                2
# 2                2
# 3                2
# 4                2
# ..             ...
# 362              2
# 363              2
# 364              1
# 365              0
# 366              0
#
# [367 rows x 11 columns]

# %%
Df = pd.read_csv(r"D:\test_lAUu6dG.csv")

submision =  Df.iloc[:,0:1]
submision
# Out:
#       Loan_ID
# 0    LP001015
# 1    LP001022
# 2    LP001031
# 3    LP001035
# 4    LP001051
# ..        ...
# 362  LP002971
# 363  LP002975
# 364  LP002980
# 365  LP002986
# 366  LP002989
#
# [367 rows x 1 columns]

# %%
submision['Loan_Status'] = y_pred

# %%
submision
# Out:
#       Loan_ID  Loan_Status
# 0    LP001015            1
# 1    LP001022            1
# 2    LP001031            1
# 3    LP001035            1
# 4    LP001051            1
# ..        ...          ...
# 362  LP002971            1
# 363  LP002975            1
# 364  LP002980            1
# 365  LP002986            1
# 366  LP002989            1
#
# [367 rows x 2 columns]

# %%
submision['Loan_Status'] = submision['Loan_Status'].replace({0: 'N', 1: 'Y'})

# %%
submision
# Out:
#       Loan_ID Loan_Status
# 0    LP001015           Y
# 1    LP001022           Y
# 2    LP001031           Y
# 3    LP001035           Y
# 4    LP001051           Y
# ..        ...         ...
# 362  LP002971           Y
# 363  LP002975           Y
# 364  LP002980           Y
# 365  LP002986           Y
# 366  LP002989           Y
#
# [367 rows x 2 columns]

# %%
submision.to_csv('model_Random_forest_Algorithm12.csv',index=False)
